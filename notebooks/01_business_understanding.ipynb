# %%
# ============================================================
# PROJECT CHARTER — Customer Churn Prediction
# ============================================================

# PROBLEM STATEMENT
# A telecom company is experiencing ~26% monthly churn rate.
# The business loses ₹3,000–5,000 per churned customer in
# re-acquisition costs. There is currently no system to
# identify at-risk customers before they leave.

# BUSINESS OBJECTIVE
# Build a machine learning model to predict which customers
# are likely to churn in the next 30 days, enabling the
# retention team to intervene proactively.

# SUCCESS METRICS (how we know the model is good enough)
# 1. AUC-ROC score > 0.85 on test set
# 2. Precision > 0.70 at the operating threshold
# 3. Model must be explainable — we need to tell marketing
#    WHY a customer is flagged, not just that they are

# KEY PERFORMANCE INDICATORS (business KPIs)
# - Monthly churn rate (target: reduce from 26% to 22%)
# - Revenue at risk = churned customers × avg monthly charge
# - Retention campaign ROI = revenue saved / campaign cost

# STAKEHOLDERS
# - Marketing team    → uses predictions to send offers
# - Finance team      → tracks revenue impact
# - Product team      → learns which features cause churn
# - You (DS/ML)       → builds and maintains the model

# DATASET
# IBM Telco Customer Churn
# Source: Kaggle
# Size: 7,043 customers × 21 features
# Target variable: Churn (Yes/No)

print("Project Charter loaded. Ready for Phase 2: Data Collection.")
